# %%
import requests
import pandas as pd

# %% [markdown]
# ## 總表讀取

# %%
url = "http://192.168.31.130:32327/games_reviews/_search?scroll=1m"  # 使用 Scroll，scroll=1m 表示 Scroll 保持活躍1分鐘
headers = {"Content-Type": "application/json"}

# 初始化 Scroll 查詢，指定要返回的欄位
data = {
    "_source": [
        "steamId",
        "tags",
        "genres",
        "features",
        "languages",
        "developers",
        "publishers",
    ],  # 查詢指定的欄位
    "query": {"match_all": {}},  # 匹配所有文件
    "size": 1000,  # 每次返回1000筆資料
}

response = requests.get(url, headers=headers, json=data)
response_json = response.json()

# 提取初始查詢的 hits 和 scroll_id
hits = response_json["hits"]["hits"]
scroll_id = response_json["_scroll_id"]

# 存儲資料的列表
data_list = [
    {
        "steamId": hit["_source"].get("steamId"),
        "tags": hit["_source"].get("tags"),
        "genres": hit["_source"].get("genres"),
        "features": hit["_source"].get("features"),
        "languages": hit["_source"].get("languages"),
        "developers": hit["_source"].get("developers"),
        "publishers": hit["_source"].get("publishers"),
    }
    for hit in hits
]

# 使用 Scroll API 繼續獲取剩餘的資料
while len(hits) > 0:
    scroll_url = "http://192.168.31.130:32327/_search/scroll"
    scroll_data = {
        "scroll": "1m",  # Scroll 保持活躍1分鐘
        "scroll_id": scroll_id,  # 使用前次查詢返回的 scroll_id 繼續查詢
    }

    scroll_response = requests.get(scroll_url, headers=headers, json=scroll_data)
    scroll_response_json = scroll_response.json()

    hits = scroll_response_json["hits"]["hits"]
    scroll_id = scroll_response_json["_scroll_id"]

    # 將新獲取的 hits 資料追加到列表中
    data_list.extend(
        [
            {
                "steamId": hit["_source"].get("steamId"),
                "tags": hit["_source"].get("tags"),
                "genres": hit["_source"].get("genres"),
                "features": hit["_source"].get("features"),
                "languages": hit["_source"].get("languages"),
                "developers": hit["_source"].get("developers"),
                "publishers": hit["_source"].get("publishers"),
            }
            for hit in hits
        ]
    )

# 將提取的資料轉換為 DataFrame
df = pd.DataFrame(data_list)

# %% [markdown]
# ## 整理儲存格資料

# %%
feature = df.columns[1:]

df_combined = pd.DataFrame({"steamId": df["steamId"]})

for column in feature:

    # 將 tags 欄位的列表轉換為字符串，並去除 , 和 [] 等符號

    df_re = df[column].apply(
        lambda x: ",".join(x).replace("[", "").replace("]", "").strip().strip('"')
    )

    df_combined[column] = df_re

df_combined
# Out:
#        steamId                                               tags  \
# 0          240  Shooter,FPS,Action,Multiplayer,Team-Based,Firs...
# 1           80  Action,FPS,Shooter,Multiplayer,First-Person,Si...
# 2       262280  Strategy,RPG,Management,Fantasy,Dungeon Crawle...
# 3      1179680  Free to Play,Sandbox,Massively Multiplayer,RPG...
# 4       688130  Psychological Horror,Precision Platformer,Diff...
# ...        ...                                                ...
# 10331  2195410  Early Access,Atmospheric,Singleplayer,Multipla...
# 10332  2293680  Survival,Crafting,Adventure,Open World Surviva...
# 10333   262100  Action,Casual,Indie,Pixel Graphics,Destruction...
# 10334  1277870  Competitive,Action,Casual,Physics,Colorful,Cut...
# 10335  1343480  Early Access,Racing,VR,Arcade,Flight,Level Edi...
#
#                                                   genres  \
# 0                                                 Action
# 1                                                 Action
# 2                                RPG,Simulation,Strategy
# 3      Adventure,Free To Play,Indie,Massively Multipl...
# 4                          Action,Adventure,Casual,Indie
# ...                                                  ...
# 10331                        Indie,Strategy,Early Access
# 10332  Action,Adventure,Indie,Massively Multiplayer,R...
# 10333                                Action,Casual,Indie
# 10334                               Action,Casual,Sports
# 10335              Racing,Simulation,Sports,Early Access
#
#                                                 features  \
# 0      Cross-Platform Multiplayer,Steam Achievements,...
# 1      Single-player,Valve Anti-Cheat enabled,Family ...
# 2      Single-player,Cross-Platform Multiplayer,Steam...
# 3      MMO,Online PvP,Online Co-op,Cross-Platform Mul...
# 4      Single-player,Online PvP,Online Co-op,Steam Ac...
# ...                                                  ...
# 10331  Single-player,Online PvP,Online Co-op,Steam Ac...
# 10332  Single-player,MMO,Online PvP,Online Co-op,Fami...
# 10333  Single-player,Online PvP,Shared/Split Screen P...
# 10334  Single-player,Online PvP,Shared/Split Screen P...
# 10335  Single-player,Online PvP,LAN PvP,Tracked Contr...
#
#                                                languages  \
# 0      English,French,German,Italian,Japanese,Korean,...
# 1      English,French,German,Italian,Spanish - Spain,...
# 2      English,German,French,Italian,Spanish - Spain,...
# 3                                                English
# 4      English,French,Italian,German,Spanish - Spain,...
# ...                                                  ...
# 10331  English,French,German,Spanish - Spain,Japanese...
# 10332                                            English
# 10333                                            English
# 10334                English,Japanese,Simplified Chinese
# 10335                                            English
#
#                   developers  \
# 0                      Valve
# 1                      Valve
# 2         Realmforge Studios
# 3               Code Club AB
# 4         Hendrik Felix Pohl
# ...                      ...
# 10331  Chimera Entertainment
# 10332      Bloodbath Studios
# 10333      Transhuman Design
# 10334                VV-LABO
# 10335           CHF Software
#
#                                               publishers
# 0                                                  Valve
# 1                                                  Valve
# 2                                  Kalypso Media Digital
# 3                                           Code Club AB
# 4                                     Hendrik Felix Pohl
# ...                                                  ...
# 10331  Chimera Entertainment,H2 Interactive (Korea an...
# 10332                                  Bloodbath Studios
# 10333                                  Transhuman Design
# 10334                                      Phoenixx Inc.
# 10335                                       CHF Software
#
# [10336 rows x 7 columns]

# %% [markdown]
# ## 取出特定資料

# %%
top_100 = pd.read_json('./top_100_followers.json', lines=True)

# %%
top_100
# Out:
#     steamId                                      name  price  reviews  \
# 0    218620                                  PAYDAY 2   9.99   643508
# 1    578080                       PUBG: BATTLEGROUNDS   0.00  2437472
# 2    271590                        Grand Theft Auto V   0.00  1748928
# 3    381210                          Dead by Daylight  19.99   706325
# 4    359550           Tom Clancy's Rainbow Six® Siege  19.99  1238727
# ..      ...                                       ...    ...      ...
# 95   349040  NARUTO SHIPPUDEN: Ultimate Ninja STORM 4  19.99    81112
# 96  2406770                                   Bodycam  33.32    22123
# 97   376210                                  The Isle  19.99    77157
# 98       10                            Counter-Strike   9.99   232758
# 99  2139460                                Once Human   0.00    93237
#
#     reviewsSteam  followers  avgPlaytime  reviewScore    releaseDate  \
# 0         431157    8278969   130.894073           90  1376366400000
# 1        2437472    3290838   292.369584           58  1513832400000
# 2        1720183    3227853   190.294729           87  1428897600000
# 3         541459    1542924   163.016052           80  1465876800000
# 4        1124284    1242981   217.958171           85  1448946000000
# ..           ...        ...          ...          ...            ...
# 95         68208     214755    21.561872           91  1454562000000
# 96         22123     213173     9.698743           74  1717821426102
# 97         77157     210768   125.833854           82  1448946000000
# 98        152877     210767   184.912729           97   973054800000
# 99         93237     210010    49.957264           72  1720583519902
#
#     earlyAccess  wishlists  copiesSold       revenue    players     owners  \
# 0         False     634700    17383397  7.732352e+07   25944969   35264283
# 1         False    1345300   114183189  4.396945e+09  114183189  138872888
# 2         False    3975400    43411442  5.387370e+08   43411442   48914193
# 3         False    1694000    12441456  1.220329e+08   16229689   18961263
# 4         False    2335300    21924953  2.118792e+08   24156736   27447527
# ..          ...        ...         ...           ...        ...        ...
# 95        False     694100     3241227  3.265382e+07    3854422    4711860
# 96         True    2674100      607363  1.705330e+07     607363     607363
# 97         True     696300     1540309  2.061464e+07    1540309    1773984
# 98        False     268400     7011176  2.944835e+07   10674642   16122482
# 99        False     799700     6132584  4.653298e+07    6132584    6132584
#
#     steamPercent itemType  totalRevenue  dlc
# 0       0.670010     game  1.230356e+08    2
# 1       1.000000     game           NaN    0
# 2       0.983564     game           NaN    1
# 3       0.766586     game  4.576770e+08    2
# 4       0.907612     game  4.929578e+08    2
# ..           ...      ...           ...  ...
# 95      0.840911     game  5.560984e+07    2
# 96      1.000000     game           NaN    0
# 97      1.000000     game           NaN    0
# 98      0.656807     game           NaN    0
# 99      1.000000     game           NaN    0
#
# [100 rows x 19 columns]

# %%
top_100_id = top_100['steamId']

# %%
top_100_id
# Out:
# 0      218620
# 1      578080
# 2      271590
# 3      381210
# 4      359550
#        ...
# 95     349040
# 96    2406770
# 97     376210
# 98         10
# 99    2139460
# Name: steamId, Length: 100, dtype: int64

# %%
df_combined['steamId'] = df_combined['steamId'].astype(int)

# %%
top_100_B = df_combined[df_combined['steamId'].isin(top_100_id)].reset_index(drop=True)
# Out:
#     steamId                                               tags  \
# 0       240  Shooter,FPS,Action,Multiplayer,Team-Based,Firs...
# 1   1245620  Souls-like,Open World,Dark Fantasy,RPG,Difficu...
# 2    427520  Automation,Base Building,Resource Management,S...
# 3   1149460  Survival,Open World Survival Craft,Base Buildi...
# 4    105600  Open World Survival Craft,Sandbox,Survival,2D,...
# ..      ...                                                ...
# 95   223750  Simulation,Flight,Free to Play,Military,Multip...
# 96  1174180  Open World,Story Rich,Western,Adventure,Multip...
# 97   813780  Strategy,RTS,City Builder,Multiplayer,Base Bui...
# 98  1142710  Strategy,Turn-Based Strategy,Grand Strategy,RT...
# 99   782330  FPS,Action,Great Soundtrack,Gore,Fast-Paced,Vi...
#
#                               genres  \
# 0                             Action
# 1                         Action,RPG
# 2   Casual,Indie,Simulation,Strategy
# 3        Action,Adventure,Simulation
# 4         Action,Adventure,Indie,RPG
# ..                               ...
# 95           Simulation,Free To Play
# 96                  Action,Adventure
# 97                          Strategy
# 98                   Action,Strategy
# 99                            Action
#
#                                              features  \
# 0   Cross-Platform Multiplayer,Steam Achievements,...
# 1   Single-player,Online PvP,Online Co-op,Steam Ac...
# 2   Single-player,Online Co-op,LAN Co-op,Cross-Pla...
# 3           Single-player,Online Co-op,Family Sharing
# 4   Single-player,Online PvP,Online Co-op,Steam Ac...
# ..                                                ...
# 95  Single-player,Online PvP,LAN PvP,Online Co-op,...
# 96  Single-player,Online PvP,Online Co-op,Steam Ac...
# 97  Single-player,Online PvP,LAN PvP,Online Co-op,...
# 98  Single-player,Online PvP,LAN PvP,Online Co-op,...
# 99  Single-player,Online PvP,Steam Achievements,St...
#
#                                             languages  \
# 0   English,French,German,Italian,Japanese,Korean,...
# 1   English,French,Italian,German,Spanish - Spain,...
# 2   English,French,Italian,German,Spanish - Spain,...
# 3   English,French,German,Portuguese - Brazil,Russ...
# 4   English,French,Italian,German,Spanish - Spain,...
# ..                                                ...
# 95  English,German,Spanish - Spain,Russian,Czech,F...
# 96  English,French,Italian,German,Spanish - Spain,...
# 97  English,French,Italian,German,Japanese,Korean,...
# 98  English,French,Italian,German,Spanish - Spain,...
# 99  English,French,Italian,German,Spanish - Spain,...
#
#                                            developers  \
# 0                                               Valve
# 1                                  FromSoftware, Inc.
# 2                                  Wube Software LTD.
# 3                                         RocketWerkz
# 4                                            Re-Logic
# ..                                                ...
# 95                                  Eagle Dynamics SA
# 96                                     Rockstar Games
# 97  Forgotten Empires,Tantalus Media,Wicked Witch,...
# 98                CREATIVE ASSEMBLY,Feral Interactive
# 99                                        id Software
#
#                                        publishers
# 0                                           Valve
# 1   FromSoftware, Inc.,Bandai Namco Entertainment
# 2                              Wube Software LTD.
# 3                                     RocketWerkz
# 4                                        Re-Logic
# ..                                            ...
# 95                              Eagle Dynamics SA
# 96                                 Rockstar Games
# 97                              Xbox Game Studios
# 98                         SEGA,Feral Interactive
# 99                             Bethesda Softworks
#
# [100 rows x 7 columns]

# %%
top_100_B.to_json('')
